# %% [markdown]
# <a href="https://colab.research.google.com/github/EdBerg21/AI-Professional-Prompts/blob/main/AR_SUCCESS_001_2024_18_Feb_RAG_Jais_13_b_Model_ipynb_txt_ipynb_txt_ipynb_(2)_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RAG Llama-2-7b Chat Model
# 📒Notebook Created by ❤️ [@prasadmahamulkar](https://www.linkedin.com/in/prasad-mahamulkar/).

# %%
# !pip install torch

# %%
from huggingface_hub import notebook_login

# %%
# !pip install transformers bitsandbytes accelerate sentence_transformers faiss-gpu
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 16.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.8/811.8 kB 18.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.7/279.7 kB 25.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 21.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 6.3 MB/s eta 0:00:00

# %%
# !huggingface-cli login --token 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
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !pip install langchain==0.0.9
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 1.3 MB/s eta 0:00:00
# ...

# %%
import torch
#from langchain import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, GenerationConfig, pipeline, BitsAndBytesConfig

# %%
# !huggingface-cli login --token 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
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ### Load model and tokenizer

# %%
base_model = "core42/jais-13b-chat"  # if you dont have huggingface account use this model:"NousResearch/Llama-2-7b-chat-hf"
tokenizer = AutoTokenizer.from_pretrained(base_model, trust_remote_code = True, use_fast=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# !pip install accelerate==0.22.0

# %%
# !pip install safetensors

# %%
import safetensors

# %%
# !pip install transformers==4.33.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 63.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 93.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# ...

# %%
# !pip install bitsandbytes==0.41.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 11.1 MB/s eta 0:00:00
# ...

# %%
model = AutoModelForCausalLM.from_pretrained(
    base_model,
    trust_remote_code=True,
    load_in_4bit= True,
    device_map="auto",
    offload_folder="/content/drive/MyDrive/offload_folder"
)
# Out:
# pytorch_model.bin.index.json:   0%|          | 0.00/42.3k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00006.bin:   0%|          | 0.00/9.99G [00:00<?, ?B/s]
# pytorch_model-00002-of-00006.bin:   0%|          | 0.00/9.79G [00:00<?, ?B/s]
# pytorch_model-00003-of-00006.bin:   0%|          | 0.00/9.96G [00:00<?, ?B/s]
# pytorch_model-00004-of-00006.bin:   0%|          | 0.00/9.75G [00:00<?, ?B/s]
# pytorch_model-00005-of-00006.bin:   0%|          | 0.00/9.79G [00:00<?, ?B/s]
# pytorch_model-00006-of-00006.bin:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     151   try:
# --> 152     _os.makedirs(config_dir)
#     153   except OSError:
#
# /usr/lib/python3.10/os.py in makedirs(name, mode, exist_ok)
#     224     try:
# --> 225         mkdir(name, mode)
#     226     except OSError:
#
# OSError: [Errno 28] No space left on device: '/root/.config/Google'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# ...

# %%
generation_config = GenerationConfig.from_pretrained(base_model, max_new_tokens = 1048)

# %%
# !pip install langchain==0.0.300
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.4 MB/s eta 0:00:00
# ...

# %%
from langchain.llms import HuggingFacePipeline

# %%
text_pipeline = pipeline(
    task="text-generation",
    model=model,
    tokenizer=tokenizer,
    generation_config=generation_config,
)

llm = HuggingFacePipeline(pipeline=text_pipeline, model_kwargs={"temperature": 0})

# %%
import locale

locale.getpreferredencoding = lambda: "UTF-8"

# %%
result = llm("What is God's sovereignty?")
print(result)
# Out:
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/nn/modules.py:224: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(f'Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.')
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:571: UserWarning: Some matrices hidden dimension is not a multiple of 64 and efficient inference kernels are not supported for these (slow). Matrix input size found: torch.Size([1, 1, 13653])
#   warn(f'Some matrices hidden dimension is not a multiple of {blocksize} and efficient inference kernels are not supported for these (slow). Matrix input size found: {A.shape}')
# A:
#
# ...

# %% [markdown]
# ### Load CSV File

# %% [markdown]
# ML-101-QandA.csv

# %% [markdown]
# prsdm/Machine-Learning-QA-dataset

# %%
import pandas as pd
df = pd.read_csv("/content/ML-101-QandA_AR.csv")
df.head()
# Out:
#                                             Question  \
# 0                                               سؤال
# 1  What is the importance of the divine call ment...
# 2  ما هي أهمية النداء الإلهي المذكور في السطور ال...
# 3   How does Baha'u'llah describe the power and i...
# 4  كيف يصف بهاء الله القوة والاستقلالية التي يمكن...
#
#                                               Answer
# 0                                              إجابة
# 1  Divine Summons Significance: The divine summon...
# 2  أهمية النداء الإلهي: النداء الإلهي هو دعوة للا...
# 3  Power and Independence: Baha’u’llah suggests t...
# 4  القوة والاستقلال: يشير بهاء الله إلى أنه من خل...

# %%
from langchain.document_loaders.csv_loader import CSVLoader
loader = CSVLoader(file_path='/content/ML-101-QandA_AR.csv', encoding='utf-8')
data = loader.load()

# %%
data[0]
# Out:
# Document(page_content='Question: سؤال\nAnswer: إجابة', metadata={'source': '/content/ML-101-QandA_AR.csv', 'row': 0})

# %% [markdown]
# ### Hugging Face Embeddings

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install sentence_transformers==2.2.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=74aa4a62d337b1e4fc382c5973b555b6c57da20b184c26f19a05055517a5cccd
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# ...

# %%
from langchain.embeddings import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="BAAI/bge-small-en-v1.5",encode_kwargs={"normalize_embeddings": True})
# Out:
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.8k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# model.onnx:   0%|          | 0.00/133M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
check_embeddings = embeddings.embed_query("What is Machine Learning?")
check_embeddings[:10]
# Out:
# [-0.0034288347233086824,
#  -0.03756481781601906,
#  -0.008593372069299221,
#  -0.015035931952297688,
#  0.056399378925561905,
#  -0.002535718958824873,
#  0.04692056402564049,
#  0.03367741405963898,
#  0.03568461164832115,
#  0.020131705328822136]

# %%
len(check_embeddings)
# Out:
# 384

# %% [markdown]
# ### Vector store: FAISS

# %%
# !pip install faiss-gpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 10.2 MB/s eta 0:00:00
# ...

# %%
from langchain.vectorstores import FAISS
vectorstore = FAISS.from_documents(documents=data,embedding=embeddings)

# %%
retriever = vectorstore.as_retriever(score_threshold = 0.8)

# %%
result = retriever.get_relevant_documents("what is machine learning?")
result
# Out:
# [Document(page_content='Question: ما هي أهمية النداء الإلهي المذكور في السطور الأولى من سورة الأصحاب؟\nAnswer: أهمية النداء الإلهي: النداء الإلهي هو دعوة للاستماع إلى آيات الله، التي تقدم الإرشاد ووعد التمكين الروحي. يدعو إلى التوجه نحو الله بتفانٍ كامل وإعلان قضيته.', metadata={'source': '/content/ML-101-QandA_AR.csv', 'row': 2}),
#  Document(page_content='Question: كيف يصف بهاء الله القوة والاستقلالية التي يمكن للمرء أن يحصل عليها من خلال الاعتراف بسيادة الله؟ كيف يصف بهاء الله القوة والاستقلالية التي يمكن للمرء أن يحصل عليها من خلال الاعتراف بسيادة الله؟\nAnswer: القوة والاستقلال: يشير بهاء الله إلى أنه من خلال الاعتراف بسيادة الله، يحصل المرء على قوة عظيمة بحيث لا تستطيع أي قوة أرضية أو معارضة أن تثير الخوف أو الاعتماد، مما يرمز إلى القوة الروحية والمرونة.', metadata={'source': '/content/ML-101-QandA_AR.csv', 'row': 4}),
# ...

# %%
from langchain.prompts import PromptTemplate

template = """
<s>[INST] <<SYS>>
Act as a Machine Learning expert. Use the context only to answer the question.
If the answer is not found in the context then end the conversation by kindly stating "I am a Machine Learning expert and I am not able to find the answer to your question."
<</SYS>>

{context}

{question} [/INST]
"""


PROMPT = PromptTemplate(template=template, input_variables=["context", "question"])
chain_type_kwargs = {"prompt": PROMPT}


from langchain.chains import RetrievalQA

chain = RetrievalQA.from_chain_type(llm=llm,
                            chain_type="stuff",
                            retriever=retriever,
                            input_key="query",
                            return_source_documents=True,
                            chain_type_kwargs=chain_type_kwargs)

# %%
# !pip install langchain==0.0.9
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.0.300
#     Uninstalling langchain-0.0.300:
#       Successfully uninstalled langchain-0.0.300
# ...

# %%
chain('Explain how does Baha'u'llah describe the power and independence gain by acknowledging God')
# Out:
# {'query': 'Explain how does Bahallah describe the power and independence gain by acknowledging God',
#  'result': '',
#  'source_documents': [Document(page_content="Question: How does Baha'u'llah describe the power and independence one can gain by acknowledging God's sovereignty?\nAnswer: Power and Independence: Baha’u’llah suggests that through the recognition of God’s sovereignty, one attains a power so great that no earthly force or opposition can induce fear or dependence, symbolizing spiritual strength and resilience.", metadata={'source': '/content/ML-101-QandA_AR.csv', 'row': 3}),
# ...

# %%
chain("what is capital of United Arab Emirates?")
# Out:
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:571: UserWarning: Some matrices hidden dimension is not a multiple of 64 and efficient inference kernels are not supported for these (slow). Matrix input size found: torch.Size([1, 1, 13653])
#   warn(f'Some matrices hidden dimension is not a multiple of {blocksize} and efficient inference kernels are not supported for these (slow). Matrix input size found: {A.shape}')
# {'query': 'what is capital of United Arab Emirates?',
#  'result': 'Answer:Answer: عاصمة دولة الإمارات العربية المتحدة هي أبوظبي.',
#  'source_documents': [Document(page_content='Question: سؤال\nAnswer: إجابة', metadata={'source': '/content/ML-101-QandA_AR.csv', 'row': 0}),
# ...

# %%
chain("شرح مفهوم الانحدار التدريجي")
# Out:
# {'query': 'شرح مفهوم الانحدار التدريجي',
#  'result': '',
#  'source_documents': [Document(page_content='Question: كيف يصف بهاء الله القوة والاستقلالية التي يمكن للمرء أن يحصل عليها من خلال الاعتراف بسيادة الله؟ كيف يصف بهاء الله القوة والاستقلالية التي يمكن للمرء أن يحصل عليها من خلال الاعتراف بسيادة الله؟\nAnswer: القوة والاستقلال: يشير بهاء الله إلى أنه من خلال الاعتراف بسيادة الله، يحصل المرء على قوة عظيمة بحيث لا تستطيع أي قوة أرضية أو معارضة أن تثير الخوف أو الاعتماد، مما يرمز إلى القوة الروحية والمرونة.', metadata={'source': '/content/ML-101-QandA_AR.csv', 'row': 4}),
#   Document(page_content='Question: ما هي أهمية النداء الإلهي المذكور في السطور الأولى من سورة الأصحاب؟\nAnswer: أهمية النداء الإلهي: النداء الإلهي هو دعوة للاستماع إلى آيات الله، التي تقدم الإرشاد ووعد التمكين الروحي. يدعو إلى التوجه نحو الله بتفانٍ كامل وإعلان قضيته.', metadata={'source': '/content/ML-101-QandA_AR.csv', 'row': 2}),
# ...

# %%
chain("how to make a coffee?")
# Out:
# {'query': 'how to make a coffee?',
#  'result': '',
#  'source_documents': [Document(page_content='Question: كيف يصف بهاء الله القوة والاستقلالية التي يمكن للمرء أن يحصل عليها من خلال الاعتراف بسيادة الله؟ كيف يصف بهاء الله القوة والاستقلالية التي يمكن للمرء أن يحصل عليها من خلال الاعتراف بسيادة الله؟\nAnswer: القوة والاستقلال: يشير بهاء الله إلى أنه من خلال الاعتراف بسيادة الله، يحصل المرء على قوة عظيمة بحيث لا تستطيع أي قوة أرضية أو معارضة أن تثير الخوف أو الاعتماد، مما يرمز إلى القوة الروحية والمرونة.', metadata={'source': '/content/ML-101-QandA_AR.csv', 'row': 4}),
#   Document(page_content='Question: سؤال\nAnswer: إجابة', metadata={'source': '/content/ML-101-QandA_AR.csv', 'row': 0}),
# ...

# %%
chain("ما هي أهمية النداء الإلهي المذكور في السطور الأولى من سورة الأصحاب؟")
# Out:
# {'query': 'ما هي أهمية النداء الإلهي المذكور في السطور الأولى من سورة الأصحاب؟',
#  'result': 'أهمية النداء الإلهي: النداء الإلهي هو دعوة للاستماع إلى آيات الله، التي تقدم الإرشاد ووعد',
#  'source_documents': [Document(page_content='Question: ما هي أهمية النداء الإلهي المذكور في السطور الأولى من سورة الأصحاب؟\nAnswer: أهمية النداء الإلهي: النداء الإلهي هو دعوة للاستماع إلى آيات الله، التي تقدم الإرشاد ووعد التمكين الروحي. يدعو إلى التوجه نحو الله بتفانٍ كامل وإعلان قضيته.', metadata={'source': '/content/ML-101-QandA_AR.csv', 'row': 2}),
#   Document(page_content='Question: في أي سياق يشير بهاء الله إلى رحلة الهجرة إلى الله، وماذا ترمز إليه؟\nAnswer: الهجرة إلى الله: الهجرة إلى الله تشير إلى رحلة روحية نحو الحضور الإلهي، تاركة وراءها العالم المادي. إنها ترمز إلى الانتقال من التعلقات الدنيوية إلى حالة من البصيرة الإلهية والقرب من الله.', metadata={'source': '/content/ML-101-QandA_AR.csv', 'row': 6}),
# ...
