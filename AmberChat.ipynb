# %% [markdown]
# <a href="https://colab.research.google.com/github/EdBerg21/AI-Professional-Prompts/blob/main/AmberChat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# !pip install xformers #xformers==0.0.20
# !pip install accelerate #accelerate==0.21.0
# !pip install transformers #transformers==4.31.0
# #ml.g5.4xlarge

# %%
# !pip install xformers==0.0.20
# !pip install accelerate==0.21.0
# !pip install transformers==4.31.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 MB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 2.0 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer
import transformers
import torch

# %%
# !huggingface-cli login --token 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
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
model = "LLM360/AmberChat"

tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto"
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/932 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/701 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/3.59G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ...

# %%
## Just having some fun with this clm

# %%
sequences = pipeline(
    """I liked the 'the Good Doctor'. The series is about """,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=200,
)

for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Result: I liked the 'the Good Doctor'. The series is about 50% accurate with the real medical procedures and treatments. But, I found the portrayal of doctors and nurses to be unrealistic and the characterization of the main character to be unsettling. I also found the writing to be poorly paced and uneven.
# The show was a big disappointment compared to the hype and the reviews I read beforehand. It was not what I expected it to be at all. There is a lot of unnecessary violence and gore in this show, and it's not something I would want to watch again. I was also disappointed that there was not a more compelling storyline or characters to root for in this show. Overall, I would not recommend this show to anyone.

# %%
sequences = pipeline(
    """
    Percy Jackson books
    """
    ,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=800,
)

for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Result:
#     Percy Jackson books
#
# * The Kane Chronicles by Rick Riordan
#     - "The Red Pyramid"
# * The Heroes of Olympus by Rick Riordan
#     - "The Blood of Olympus"
# * The Trials of Apollo by Rick Riordan
#     - "The Dark Prophecy"
# * The Kane Chronicles: The Throne of Fire by Rick Riordan
#     - "The Throne of Fire"
# * The Kane Chronicles: The Battle of the Labyrinth by Rick Riordan
#     - "The Battle of the Labyrinth"
# * The Kane Chronicles: The Last Olympian by Rick Riordan
#     - "The Last Olympian"
# * The Kane Chronicles: The Son of Neptune by Rick Riordan
#     - "The Son of Neptune"
# * The Kane Chronicles: The Mark of Athena by Rick Riordan
#     - "The Mark of Athena"
# * The Kane Chronicles: The Demigod's Dilemma by Rick Riordan
#     - "The Demigod's Dilemma"
# * The Kane Chronicles: The Burning Maze by Rick Riordan
#     - "The Burning Maze"
#
# ...
