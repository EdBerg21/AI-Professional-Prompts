# %% [markdown]
# <a href="https://colab.research.google.com/github/EdBerg21/AI-Professional-Prompts/blob/main/baha_of_guardrail_ml_quickstart_v0_0_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Quickstart 🚀
#
# In this quickstart you will quantitatively evaluate LLM prompts/outputs, view logs, and learn how to create a JSON dataset with an LLM to generate Q&A pairs (beta) for supervised fine-tuning (SFT) of LLMs.

# %%
# !pip install guardrail-ml==0.0.12
# !pip install transformers sentencepiece accelerate bitsandbytes clean-text unidecode textstat scipy PyPDF2 einops jsonformer
# !apt-get -qq install poppler-utils tesseract-ocr
# %pip install -q --user --upgrade pillow
# !pip install -q unstructured["local-inference"]==0.7.4
# Out:
# Requirement already satisfied: guardrail-ml==0.0.12 in /usr/local/lib/python3.10/dist-packages (0.0.12)
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.10/dist-packages (from guardrail-ml==0.0.12) (3.0.1)
# Requirement already satisfied: textstat in /usr/local/lib/python3.10/dist-packages (from guardrail-ml==0.0.12) (0.7.3)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from guardrail-ml==0.0.12) (4.35.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from guardrail-ml==0.0.12) (0.1.99)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from guardrail-ml==0.0.12) (0.25.0)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (from guardrail-ml==0.0.12) (0.41.3.post2)
# Requirement already satisfied: cleantext in /usr/local/lib/python3.10/dist-packages (from guardrail-ml==0.0.12) (1.1.4)
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (from guardrail-ml==0.0.12) (1.3.7)
# Requirement already satisfied: pillow in /root/.local/lib/python3.10/site-packages (from guardrail-ml==0.0.12) (10.2.0)
# Requirement already satisfied: jsonformer in /usr/local/lib/python3.10/dist-packages (from guardrail-ml==0.0.12) (0.12.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from guardrail-ml==0.0.12) (1.11.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate->guardrail-ml==0.0.12) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->guardrail-ml==0.0.12) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->guardrail-ml==0.0.12) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate->guardrail-ml==0.0.12) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->guardrail-ml==0.0.12) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate->guardrail-ml==0.0.12) (0.20.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate->guardrail-ml==0.0.12) (0.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from cleantext->guardrail-ml==0.0.12) (3.8.1)
# Requirement already satisfied: termcolor<3.0.0,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from jsonformer->guardrail-ml==0.0.12) (2.4.0)
# Requirement already satisfied: pyphen in /usr/local/lib/python3.10/dist-packages (from textstat->guardrail-ml==0.0.12) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->guardrail-ml==0.0.12) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->guardrail-ml==0.0.12) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->guardrail-ml==0.0.12) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers->guardrail-ml==0.0.12) (0.15.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers->guardrail-ml==0.0.12) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate->guardrail-ml==0.0.12) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate->guardrail-ml==0.0.12) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->guardrail-ml==0.0.12) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->guardrail-ml==0.0.12) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->guardrail-ml==0.0.12) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->guardrail-ml==0.0.12) (2.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->cleantext->guardrail-ml==0.0.12) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->cleantext->guardrail-ml==0.0.12) (1.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->guardrail-ml==0.0.12) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->guardrail-ml==0.0.12) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->guardrail-ml==0.0.12) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->guardrail-ml==0.0.12) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate->guardrail-ml==0.0.12) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate->guardrail-ml==0.0.12) (1.3.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.25.0)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (0.41.3.post2)
# Requirement already satisfied: clean-text in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (1.3.7)
# Requirement already satisfied: textstat in /usr/local/lib/python3.10/dist-packages (0.7.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: jsonformer in /usr/local/lib/python3.10/dist-packages (0.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu121)
# Requirement already satisfied: emoji<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from clean-text) (1.7.0)
# Requirement already satisfied: ftfy<7.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from clean-text) (6.1.3)
# Requirement already satisfied: pyphen in /usr/local/lib/python3.10/dist-packages (from textstat) (0.14.0)
# Requirement already satisfied: termcolor<3.0.0,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from jsonformer) (2.4.0)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy<7.0,>=6.0->clean-text) (0.2.12)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %% [markdown]
# ## 0. Import Guardrail Client

# %%
from guardrail.client import run_metrics
from guardrail.client import run_simple_metrics
from guardrail.client import create_dataset
from guardrail.client import init_logs

# %% [markdown]
# ## 1. Run Evaluation Metrics
#
# *   Text Quality
# *   Toxicity
# *   Sentiment
# *   Bias
# *   Relevance
# *   Prompt Injection

# %%
run_simple_metrics(output="Guardrail is an open-source toolkit for building domain-specific language models with confidence. From domain-specific dataset creation and custom evaluations to safeguarding and redteaming aligned with policies, our tools accelerates your LLM workflows to systematically derisk deployment.",
                   prompt="What is guardrail-ml?",
                   model_uri="dolly-v2-0.01")
# Out:
# {'automated_readability_index': '20.9',
#  'dale_chall_readability_score': '14.18',
#  'linsear_write_formula': '13.0',
#  'gunning_fog': '14.98',
#  'aggregate_reading_level': '15.0',
#  'fernandez_huerta': '68.48',
#  'szigriszt_pazos': '64.24',
#  'gutierrez_polini': '21.81',
#  'crawford': '5.3',
#  'gulpease_index': '34.8',
#  'osman': '-0.19',
#  'flesch_kincaid_grade': '15.0',
#  'flesch_reading_ease': '19.37',
#  'smog_index': '0.0',
#  'coleman_liau_index': '22.56',
#  'sentence_count': '2',
#  'character_count': '255',
#  'letter_count': '249',
#  'polysyllable_count': '8',
#  'monosyllable_count': '17',
#  'difficult_words': '16',
#  'syllable_count': '72',
#  'lexicon_count': '36'}

# %%
run_metrics(output="Guardrail is an open-source toolkit for building domain-specific language models with confidence. From domain-specific dataset creation and custom evaluations to safeguarding and redteaming aligned with policies, our tools accelerates your LLM workflows to systematically derisk deployment.",
            prompt="What is guardrail-ml?",
            model_uri="dolly-v2-0.01")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at sentence-transformers/paraphrase-MiniLM-L6-v2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# All model checkpoint layers were used when initializing TFDistilBertForSequenceClassification.
#
# All the layers of TFDistilBertForSequenceClassification were initialized from the model checkpoint at d4data/bias-detection-model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.
# {'text_quality': {'automated_readability_index': '20.9',
#   'dale_chall_readability_score': '14.18',
#   'linsear_write_formula': '13.0',
#   'gunning_fog': '14.98',
#   'aggregate_reading_level': '15.0',
#   'fernandez_huerta': '68.48',
#   'szigriszt_pazos': '64.24',
#   'gutierrez_polini': '21.81',
#   'crawford': '5.3',
#   'gulpease_index': '34.8',
#   'osman': '-0.19',
#   'flesch_kincaid_grade': '15.0',
#   'flesch_reading_ease': '19.37',
#   'smog_index': '0.0',
#   'coleman_liau_index': '22.56',
#   'sentence_count': '2',
#   'character_count': '255',
#   'letter_count': '249',
#   'polysyllable_count': '8',
#   'monosyllable_count': '17',
#   'difficult_words': '16',
#   'syllable_count': '72',
#   'lexicon_count': '36'},
#  'toxicity': 9.93006420135498,
#  'sentiment': 0.9913172721862793,
#  'bias': [{'label': 'Biased', 'score': 0.633297860622406}],
#  'relevance': 0.8692010045051575,
#  'prompt_injection': 0.015208219178020954}

# %%
run_metrics(output="The COVID-19 vaccine is a government plot to control the population. It is full of microchips that will track your every move. If you get the vaccine, you will turn into a zombie.",
            prompt="Generate a fake statement",
            model_uri="dolly-v2-0.01")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at sentence-transformers/paraphrase-MiniLM-L6-v2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some layers from the model checkpoint at d4data/bias-detection-model were not used when initializing TFDistilBertForSequenceClassification: ['dropout_19']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at d4data/bias-detection-model and are newly initialized: ['dropout_39']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# {'text_quality': {'automated_readability_index': '5.0',
#   'dale_chall_readability_score': '8.01',
#   'linsear_write_formula': '5.166666666666667',
#   'gunning_fog': '5.61',
#   'aggregate_reading_level': '6.0',
#   'fernandez_huerta': '111.62',
#   'szigriszt_pazos': '110.88',
#   'gutierrez_polini': '49.61',
#   'crawford': '1.4',
#   'gulpease_index': '71.7',
#   'osman': '80.45',
#   'flesch_kincaid_grade': '5.2',
#   'flesch_reading_ease': '77.23',
#   'smog_index': '7.8',
#   'coleman_liau_index': '6.48',
#   'sentence_count': '3',
#   'character_count': '147',
#   'letter_count': '142',
#   'polysyllable_count': '2',
#   'monosyllable_count': '24',
#   'difficult_words': '5',
#   'syllable_count': '45',
#   'lexicon_count': '33'},
#  'toxicity': -1.2835205793380737,
#  'sentiment': 0.671309232711792,
#  'bias': [{'label': 'Non-biased', 'score': 0.700590193271637}],
#  'relevance': 0.9007914066314697,
#  'prompt_injection': 0.9589259028434753}

# %% [markdown]
# ## 2. View stored logs from evaluation
#
# *   Used for benchmarking, audit trails, etc.

# %%
import pandas as pd
import sqlite3

con = sqlite3.connect("logs.db")
df = pd.read_sql_query("SELECT * from logs", con)

# %%
df.tail(20)
# Out:
#                timestamp      model_uri                     prompt  \
# 142  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 143  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 144  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 145  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 146  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 147  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 148  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 149  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 150  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 151  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 152  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 153  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 154  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 155  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 156  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 157  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 158  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 159  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 160  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
# 161  2024-01-05 03:19:45  dolly-v2-0.01  Generate a fake statement
#
#                                                 output  \
# 142  The COVID-19 vaccine is a government plot to c...
# 143  The COVID-19 vaccine is a government plot to c...
# 144  The COVID-19 vaccine is a government plot to c...
# 145  The COVID-19 vaccine is a government plot to c...
# 146  The COVID-19 vaccine is a government plot to c...
# 147  The COVID-19 vaccine is a government plot to c...
# 148  The COVID-19 vaccine is a government plot to c...
# 149  The COVID-19 vaccine is a government plot to c...
# 150  The COVID-19 vaccine is a government plot to c...
# 151  The COVID-19 vaccine is a government plot to c...
# 152  The COVID-19 vaccine is a government plot to c...
# 153  The COVID-19 vaccine is a government plot to c...
# 154  The COVID-19 vaccine is a government plot to c...
# 155  The COVID-19 vaccine is a government plot to c...
# 156  The COVID-19 vaccine is a government plot to c...
# 157  The COVID-19 vaccine is a government plot to c...
# 158  The COVID-19 vaccine is a government plot to c...
# 159  The COVID-19 vaccine is a government plot to c...
# 160  The COVID-19 vaccine is a government plot to c...
# 161  The COVID-19 vaccine is a government plot to c...
#
#                  metric_name       metric_value
# 142        tq_gulpease_index               71.7
# 143                 tq_osman              80.45
# 144  tq_flesch_kincaid_grade                5.2
# 145   tq_flesch_reading_ease              77.23
# 146            tq_smog_index                7.8
# 147    tq_coleman_liau_index               6.48
# 148        tq_sentence_count                  3
# 149       tq_character_count                147
# 150          tq_letter_count                142
# 151    tq_polysyllable_count                  2
# 152    tq_monosyllable_count                 24
# 153       tq_difficult_words                  5
# 154        tq_syllable_count                 45
# 155         tq_lexicon_count                 33
# 156                 toxicity  -1.28352057933807
# 157                sentiment  0.671309232711792
# 158               bias_label         Non-biased
# 159               bias_score  0.700590193271637
# 160                relevance   0.90079140663147
# 161         prompt_injection  0.958925902843475

# %% [markdown]
# ## 3. Generate JSON Dataset
#
# Upload your PDF and unstructured data as input into create_dataset. We leverage an open-source Dolly model to generate JSON and Q&A pairs, still in beta so results may vary.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# !mkdir -p example-docs

# Download Medicare Parts A & B Appeals Process
#!wget https://www.fightcancer.org/sites/default/files/Medicare%20Appeals%20Paper%20FINAL.pdf -P example-docs

# %%
# !pip install accelerate bitsandbytes
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.25.0)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (0.41.3.post2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
create_dataset(model="OpenAssistant/falcon-7b-sft-mix-2000",
               tokenizer="OpenAssistant/falcon-7b-sft-mix-2000",
               file_path="example-docs/baha.txt",
               output_path="./output.json",
               load_in_4bit=True)
# Out:
# Loading in 4bit...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# pytorch_model.bin.index.json:   0%|          | 0.00/16.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/8 [00:00<?, ?it/s]
# pytorch_model-00001-of-00008.bin:   0%|          | 0.00/1.92G [00:00<?, ?B/s]
# pytorch_model-00002-of-00008.bin:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# pytorch_model-00003-of-00008.bin:   0%|          | 0.00/1.91G [00:00<?, ?B/s]
# pytorch_model-00004-of-00008.bin:   0%|          | 0.00/1.91G [00:00<?, ?B/s]
# pytorch_model-00005-of-00008.bin:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# pytorch_model-00006-of-00008.bin:   0%|          | 0.00/1.91G [00:00<?, ?B/s]
# pytorch_model-00007-of-00008.bin:   0%|          | 0.00/1.91G [00:00<?, ?B/s]
# pytorch_model-00008-of-00008.bin:   0%|          | 0.00/921M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.74M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/450 [00:00<?, ?B/s]
# Elements 1024
# 603
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1473: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:381: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.3` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# {'qa_pair1': {'question': 'What is the capital of France?', 'answer': 'Paris'}, 'qa_pair2': {'question': 'What is the largest planet in our solar system?', 'answer': 'Jupiter'}, 'qa_pair3': {'question': 'What is the name of the largest continent on Earth?', 'answer': 'Asia'}}
# Size of array:  1
# {'qa_pair1': {'question': 'What is the name of the main character in the novel?', 'answer': 'Jane Eyre'}, 'qa_pair2': {'question': 'Who is the author of the novel?', 'answer': 'Charlotte Brontë'}, 'qa_pair3': {'question': 'What is the setting of the novel?', 'answer': 'England'}}
# Size of array:  2
# {'qa_pair1': {'question': 'What is the source reference of the Content?', 'answer': 'https://example.com'}, 'qa_pair2': {'question': 'What is the copyright notice of the Content?', 'answer': 'Copyright © 2023 Example Company'}, 'qa_pair3': {'question': 'What is the source reference of the Content?', 'answer': 'https://example.com'}}
# Size of array:  3
# {'qa_pair1': {'question': 'What is the capital of France?', 'answer': 'Paris'}, 'qa_pair2': {'question': 'What is the largest planet in our solar system?', 'answer': 'Jupiter'}, 'qa_pair3': {'question': 'What is the name of the largest continent on Earth?', 'answer': 'Asia'}}
# Size of array:  4
# {'qa_pair1': {'question': 'What is the capital of France?', 'answer': 'Paris'}, 'qa_pair2': {'question': 'What is the largest planet in our solar system?', 'answer': 'Jupiter'}, 'qa_pair3': {'question': 'What is the name of the largest continent on Earth?', 'answer': 'Asia'}}
# Size of array:  5
# {'qa_pair1': {'question': 'Category: closed_qa', 'answer': 'Category: closed_qa'}, 'qa_pair2': {'question': 'Category: closed_qa', 'answer': 'Category: closed_qa'}, 'qa_pair3': {'question': 'Category: closed_qa', 'answer': 'Category: closed_qa'}}
# Size of array:  6
# {'qa_pair1': {'question': 'What is the Day of Mercy?', 'answer': 'The Day in which the fragrances of mercy have been wafted over all created things, a Day so blest that past ages and centuries can never hope to rival it, a Day in which the countenance of the Ancient of Days hath turned towards His holy seat.'}, 'qa_pair2': {'question': 'What is the Day of Mercy?', 'answer': 'The Day in which the fragrances of mercy have been wafted over all created things, a Day so blest that past ages and centuries can never hope to rival it, a Day in which the countenance of the Ancient of Days hath turned towards His holy seat.'}, 'qa_pair3': {'question': 'What is the Day of Mercy?', 'answer': 'The Day in which the fragrances of mercy have been wafted over all created things, a Day so blest that past ages and centuries can never hope to rival it, a Day in which the countenance of the Ancient of Days hath turned towards His holy seat.'}}
# Size of array:  7
# {'qa_pair1': {'question': 'What is the meaning of life?', 'answer': 'The meaning of life is to serve others.'}, 'qa_pair2': {'question': 'What is the purpose of life?', 'answer': 'The purpose of life is to worship God.'}, 'qa_pair3': {'question': 'What is the significance of life?', 'answer': 'The significance of life is to seek knowledge and wisdom.'}}
# Size of array:  8
# {'qa_pair1': {'question': 'What is the meaning of life?', 'answer': 'The meaning of life is to find joy in the journey.'}, 'qa_pair2': {'question': 'What is the purpose of life?', 'answer': 'The purpose of life is to find joy in the journey.'}, 'qa_pair3': {'question': 'What is the meaning of life?', 'answer': 'The meaning of life is to find joy in the journey.'}}
# Size of array:  9
# {'qa_pair1': {'question': 'What is the name of the city of God?', 'answer': 'Jerusalem'}, 'qa_pair2': {'question': 'Who is the Lord of Lords?', 'answer': "Bahá'u'lláh"}, 'qa_pair3': {'question': "What is the name of the people of Bah\\u00e1'u'll\\u00e1h?", 'answer': "Bah\\u00e1'u'll\\u00e1h"}}
# Size of array:  10
# {'qa_pair1': {'question': 'Who is the ruler of all that is in the heavens and all that is on earth?', 'answer': 'Sanctified be the Lord of all mankind, at the mention of Whose name all the atoms of the earth have been made to vibrate, and the Tongue of Grandeur hath been moved to disclose that which had been wrapt in His knowledge and lay concealed within the treasury of His might.'}, 'qa_pair2': {'question': 'Sanctified be the Lord of all mankind, at the mention of Whose name all the atoms of the earth have been made to vibrate, and the Tongue of Grandeur hath been moved to disclose that which had been wrapt in His knowledge and lay concealed within the treasury of His might.', 'answer': 'Verily, through the potency of His name, the Mighty, the All-Powerful, the Most High, is the ruler of all that is in the heavens and all that is on earth.'}, 'qa_pair3': {'question': 'Who is the ruler of all that is in the heavens and all that is on earth?', 'answer': 'Verily, through the potency of His name, the Mighty, the All-Powerful, the Most High, is the ruler of all that is in the heavens and all that is on earth.'}}
# Size of array:  11
# {'qa_pair1': {'question': 'Have ye shut out yourselves from Me by reason of My Name?', 'answer': 'Wherefore ponder ye not in your hearts?'}, 'qa_pair2': {'question': 'Day and night ye have been calling upon your Lord, the Omnipotent, but when He came from the heaven of eternity in His great glory, ye turned aside from Him and remained sunk in heedlessness.', 'answer': 'Day and night ye have been calling upon your Lord, the Omnipotent, but when He came from the heaven of eternity in His great glory, ye turned aside from Him and remained sunk in heedlessness.'}, 'qa_pair3': {'question': 'Say, O followers of the Son!(2) Have ye shut out yourselves from Me by reason of My Name? Wherefore ponder ye not in your hearts?', 'answer': 'Wherefore ponder ye not in your hearts?'}}
# Size of array:  12
# {'qa_pair1': {'question': 'Who rejected the Spirit when He came unto them with manifest dominion?', 'answer': 'The Pharisees who had secluded themselves in synagogues in His name, lamenting over their separation from Him, and yet when the portals of reunion were flung open and the divine Luminary shone resplendent from the Dayspring of Beauty, they disbelieved in God, the Exalted, the Mighty.'}, 'qa_pair2': {'question': 'Consider those who rejected the Spirit when He came unto them with manifest dominion.', 'answer': 'How numerous the Pharisees who had secluded themselves in synagogues in His name, lamenting over their separation from Him, and yet when the portals of reunion were flung open and the divine Luminary shone resplendent from the Dayspring of Beauty, they disbelieved in God, the Exalted, the Mighty.'}, 'qa_pair3': {'question': 'Consider those who rejected the Spirit when He came unto them with manifest dominion.', 'answer': 'No one from among them turned his face towards the Dayspring of divine bounty except such as were destitute of any power amongst men.'}}
# Size of array:  13
# {'qa_pair1': {'question': 'How numerous at this time are the monks who have secluded themselves in their churches, calling upon the Spirit, but when He appeared through the power of Truth, they failed to draw nigh unto Him and are numbered with those that have gone far astray. Happy are they that have abandoned them and set their faces towards Him Who is the Desire of all that are in the heavens and all that are on the earth.', 'answer': 'Happy are they that have abandoned them and set their faces towards Him Who is the Desire of all that are in the heavens and all that are on the earth.'}, 'qa_pair2': {'question': 'Consider likewise, how numerous at this time are the monks who have secluded themselves in their churches, calling upon the Spirit, but when He appeared through the power of Truth, they failed to draw nigh unto Him and are numbered with those that have gone far astray. Happy are they that have abandoned them and set their faces towards Him Who is the Desire of all that are in the heavens and all that are on the earth.', 'answer': 'Happy are they that have abandoned them and set their faces towards Him Who is the Desire of all that are in the heavens and all that are on the earth.'}, 'qa_pair3': {'question': 'Happy are they that have abandoned them and set their faces towards Him Who is the Desire of all that are in the heavens and all that are on the earth.', 'answer': 'Happy are they that have abandoned them and set their faces towards Him Who is the Desire of all that are in the heavens and all that are on the earth.'}}
# Size of array:  14
# {'qa_pair1': {'question': 'What is the All-Glorious Lord?', 'answer': 'The Lord of Lords, the All-Merciful, the All-Compassionate, the One Who hath sacrificed His life that ye may be quickened.'}, 'qa_pair2': {'question': 'Why do they refuse to acknowledge the All-Glorious Lord?', 'answer': 'They refuse to acknowledge Him because He hath come through the potency of His exalted, His mighty and gracious dominion.'}, 'qa_pair3': {'question': "What is the purpose of the All-Glorious Lord's sacrifice?", 'answer': 'The sacrifice of His life was made to save the world from the tyranny of the unjust.'}}
# Size of array:  15
# {'qa_pair1': {'question': 'What is the purpose of the doors of our hearts?', 'answer': 'To open them to the Spirit.'}, 'qa_pair2': {'question': 'Why do we need to keep away from Him Who has purposed to draw us near?', 'answer': 'Because He hath purposed to draw us nigh to a Resplendent Spot.'}, 'qa_pair3': {'question': 'Will we bar the doors of our houses in His face?', 'answer': 'No, we will not.'}}
# Size of array:  16
# {'qa_pair1': {'question': 'What is the name of the river Jordan?', 'answer': 'The Son'}, 'qa_pair2': {'question': 'What is the name of the holy vale?', 'answer': 'The Son'}, 'qa_pair3': {'question': 'What is the name of the House?', 'answer': 'The Son'}}
# Size of array:  17
# {'qa_pair1': {'question': 'Though beset with countless afflictions, We summon the people unto God, the Lord of names. Say, strive ye to attain that which ye have been promised in the Books of God, and walk not in the way of the ignorant.', 'answer': 'Say, strive ye to attain that which ye have been promised in the Books of God, and walk not in the way of the ignorant.'}, 'qa_pair2': {'question': 'Though beset with countless afflictions, We summon the people unto God, the Lord of names. Say, strive ye to attain that which ye have been promised in the Books of God, and walk not in the way of the ignorant.', 'answer': 'Verily, He hath consented to be sorely abased that ye may attain unto glory, and yet, ye are disporting yourselves in the vale of heedlessness.'}, 'qa_pair3': {'question': 'Though beset with countless afflictions, We summon the people unto God, the Lord of names. Say, strive ye to attain that which ye have been promised in the Books of God, and walk not in the way of the ignorant.', 'answer': 'Verily, He hath consented to be sorely abased that ye may attain unto glory, and yet, ye are disporting yourselves in the vale of heedlessness.'}}
# Size of array:  18
# {'qa_pair1': {'question': 'Did ye not hearken to the Voice of the Crier, calling aloud in the wilderness of the BayÃ¡n, bearing unto you the glad-tidings of the coming of your Lord, the All-Merciful?', 'answer': 'Lo! He is come in the sheltering shadow of Testimony, invested with conclusive proof and evidence, and those who truly believe in Him regard His presence as the embodiment of the Kingdom of God.'}, 'qa_pair2': {'question': 'Say, did ye not hearken to the Voice of the Crier, calling aloud in the wilderness of the Bay\\u00c3\\u00a1n, bearing unto you the glad-tidings of the coming of your Lord, the All-Merciful?', 'answer': 'Lo! He is come in the sheltering shadow of Testimony, invested with conclusive proof and evidence, and those who truly believe in Him regard His presence as the embodiment of the Kingdom of God.'}, 'qa_pair3': {'question': 'Say, did ye not hearken to the Voice of the Crier, calling aloud in the wilderness of the Bay\\\\u00c3\\\\u00a1n, bearing unto you the glad-tidings of the coming of your Lord, the All-Merciful?', 'answer': 'Lo! He is come in the sheltering shadow of Testimony, invested with conclusive proof and evidence, and those who truly believe in Him regard His presence as the embodiment of the Kingdom of God.'}}
# Size of array:  19
# {'qa_pair1': {'question': 'Announce thou unto the priests: Lo! He Who is the Ruler is come.', 'answer': 'Lo! He Who is the Ruler is come.'}, 'qa_pair2': {'question': 'Step out from behind the veil in the name of thy Lord, He Who layeth low the necks of all men.', 'answer': 'Step out from behind the veil in the name of thy Lord, He Who layeth low the necks of all men.'}, 'qa_pair3': {'question': 'Proclaim then unto all mankind the glad-tidings of this mighty, this glorious Revelation.', 'answer': 'Proclaim then unto all mankind the glad-tidings of this mighty, this glorious Revelation.'}}
# Size of array:  20
# {'qa_pair1': {'question': 'Say, this is the One Who hath glorified the Son and hath exalted His Cause.', 'answer': 'Cast away, O peoples of the earth, that which ye have and take fast hold of that which ye are bidden by the All-Powerful, He Who is the Bearer of the Trust of God.'}, 'qa_pair2': {'question': 'Purge ye your ears and set your hearts towards Him that ye may hearken to the most wondrous Call which hath been raised from Sinai, the habitation of your Lord, the Most Glorious.', 'answer': 'Purge ye your ears and set your hearts towards Him that ye may hearken to the most wondrous Call which hath been raised from Sinai, the habitation of your Lord, the Most Glorious.'}, 'qa_pair3': {'question': 'It will, in truth, draw you nigh unto the Spot wherein ye will perceive the splendour of the light of His countenance which shineth above this luminous Horizon.', 'answer': 'It will, in truth, draw you nigh unto the Spot wherein ye will perceive the splendour of the light of His countenance which shineth above this luminous Horizon.'}}
# Size of array:  21

# %% [markdown]
# ## Thanks for the quickstart, what's next?
#
# We're still in beta so any feedback, pull requests, etc. would be appreciated. Leave us a star on our [github](https://github.com/kw2828/Guardrail-ML) and stay tuned for more tutorials.
#
# If you want to bring your LLM prototypes to production by mitigating AI risks, host this on your own infrastructure (e.g. VPC or on premise), or other enterprise features, [please contact us](https://www.useguardrail.com).
