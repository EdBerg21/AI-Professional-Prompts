# %% [markdown]
# <a href="https://colab.research.google.com/github/EdBerg21/AI-Professional-Prompts/blob/main/SUPER_Jais_RAG_finetune_0001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers==4.32.0
# Out:
# Collecting transformers==4.32.0
#   Downloading transformers-4.32.0-py3-none-any.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 47.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.32.0)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 23.0 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers==4.32.0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers==4.32.0) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.32.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.32.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.32.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.32.0) (2024.2.2)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.37.2
#     Uninstalling transformers-4.37.2:
#       Successfully uninstalled transformers-4.37.2
# Successfully installed tokenizers-0.13.3 transformers-4.32.0

# %%
# !pip install accelerate
# Out:
# Collecting accelerate
#   Downloading accelerate-0.27.2-py3-none-any.whl (279 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.27.2

# %%
# !pip install bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy->bitsandbytes) (1.25.2)
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.42.0

# %%
# !pip install safetensors
# Out:
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (0.4.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import safetensors

# %%
# -*- coding: utf-8 -*-

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
model_path = "core42/jais-13b"

device = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path, load_in_8bit=True, trust_remote_code=True)


def get_response(text,tokenizer=tokenizer,model=model):
    input_ids = tokenizer(text, return_tensors="pt").input_ids
    inputs = input_ids.to(device)
    input_len = inputs.shape[-1]
    generate_ids = model.generate(
        inputs,
        top_p=0.9,
        temperature=0.3,
        max_length=200,
        min_length=input_len + 4,
        repetition_penalty=1.2,
        do_sample=True,
    )
    response = tokenizer.batch_decode(
        generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True
    )[0]
    return response
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.25k [00:00<?, ?B/s]
# configuration_jais.py:   0%|          | 0.00/6.76k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/core42/jais-13b:
# - configuration_jais.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_jais.py:   0%|          | 0.00/68.6k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/core42/jais-13b:
# - modeling_jais.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin.index.json:   0%|          | 0.00/42.3k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/6 [00:00<?, ?it/s]
# pytorch_model-00001-of-00006.bin:   0%|          | 0.00/9.99G [00:00<?, ?B/s]
# pytorch_model-00002-of-00006.bin:   0%|          | 0.00/9.79G [00:00<?, ?B/s]
# pytorch_model-00003-of-00006.bin:   0%|          | 0.00/9.96G [00:00<?, ?B/s]
# pytorch_model-00004-of-00006.bin:   0%|          | 0.00/9.75G [00:00<?, ?B/s]
# pytorch_model-00005-of-00006.bin:   0%|          | 0.00/9.79G [00:00<?, ?B/s]
# pytorch_model-00006-of-00006.bin:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# عاصمة دولة الإمارات العربية المتحدة هوجمت من قبل القوات الإيرانية.
# The capital of UAE is Abu Dhabi. The population of the country was estimated to be 8,979,000 in 2013 with a growth rate of 2.6%.
#
# UAE has been ranked as one of the most attractive countries for foreign direct investment (FDI) by World Bank's Doing Business Report since 2008 and it continues to rank high on this list every year. It also ranks first among Arab nations when it comes to ease of doing business according to the same report.
#
# In terms of economic freedom, UAE has been rated at 7th place globally out of 179 economies surveyed by Heritage Foundation/Wall Street Journal Index of Economic Freedom 2014-2015. This rating places UAE ahead of many developed economies such as Australia, Canada or New Zealand which have higher GDP per capita than UAE but are not considered economically free due to their lack of political freedoms.
#
# UAE economy depends heavily on oil production and exports accounting for more than 50% of

# %%
text= "عاصمة دولة الإمارات العربية المتحدة ه"
print(get_response(text))
# Out:
# عاصمة دولة الإمارات العربية المتحدة هليوبوليس الجديدة هي مدينة سكنية جديدة تقع على بعد 45 كم من القاهرة, وهي واحدة من المدن الأكثر شعبية في مصر.

# %%
text = "The capital of UAE is"
print(get_response(text))
# Out:
# The capital of UAE is Abu Dhabi, which has a population of 2.4 million people and an area of 6300 square kilometers (2400 sq mi). The city's skyline features the world-famous Burj Khalifa tower that stands at 828 meters (2723 ft) tall; it was built in 2010 to become the tallest building on Earth until Dubai surpassed its height with the construction of the Burj Dubai tower in 2013.[1]
#
# Abu Dhabi is also home to Al Ain, one of the oldest cities in the region. It lies about 200 km from the capital and boasts some of the most spectacular natural scenery in the country: the Hajar Mountains rise up out of the desert like giant sandstone sentries guarding the oasis below them. This mountain range forms part of the Arabian Peninsula's largest protected area – Al Ain Oasis Reserve.

# %%
text = "Who was Baha'u'llah?"
print(get_response(text))
# Out:
# Who was Baha'u'llah?
#
# Baha'u'llah, the founder of the Baha'i Faith. He is also known as "the Bab" (meaning 'gate'). The Babi movement began in Iran and spread to other countries around the world during his lifetime from 1819-1850 CE. In 1852 he announced that he had been appointed by God to be a prophet for this age; thus beginning the Baha'i faith which has since grown into one of the largest religions on earth with over five million members worldwide.

# %%
text = "ما هو أعلى جبل في العالم؟";
print(get_response(text))
# Out:
# ما هو أعلى جبل في العالم؟" سأل. "أعلى قمة على وجه الأرض هي إيفرست ، وهي ترتفع عن سطح البحر ثمانية وعشرين ألف قدم".

# %%
text = "كم عدد قارات العالم؟";
print(get_response(text))
# Out:
# كم عدد قارات العالم؟" سأل. "هل تعرف ذلك حتى الآن، أم أنك بحاجة إلى مساعدة في الرياضيات الخاصة بك؟"

# %%
text = "Who painted the Mona Lisa?";
print(get_response(text))
# Out:
# Who painted the Mona Lisa?
#
# The question of who painted The Mona Lisa has been a subject of debate for centuries. Leonardo da Vinci is widely believed to be responsible, but there are many other theories about its creator and originator. Some believe that it was actually completed by one of his assistants or students; others say that he merely sketched out some ideas on paper before passing them off as his own work. Whatever you think, this painting will always remain an enigma in art history!

# %%
text = "What is the largest ocean on Earth?";
print(get_response(text))
# Out:
# What is the largest ocean on Earth?
#
# The world's oceans cover about 71% of our planet, and are home to a huge variety of marine life. The five biggest oceans in the world by area are: Pacific Ocean (68 million square kilometres), Atlantic Ocean (66 million square kilometres), Indian Ocean (34 million square kilometres), Arctic Ocean (15 million square kilometres) and Southern Ocean (12 million square kilometres).
#
# How deep does the deepest part of the sea go?
#
# The Mariana Trench off the coast of Guam holds the title for being the deepest point in the sea at 10,924 metres below sea level - more than twice as deep as Mount Everest! It was discovered during an expedition led by US explorer Commander Byrd in 1960 that found this incredible depth.

# %%
text = "متى تأسست مدينة سلفادور؟";
print(get_response(text))
# Out:
# متى تأسست مدينة سلفادور؟" سأل. "هل تعرف ذلك؟"

# %%
text = "What is the process of photosynthesis?";
print(get_response(text))
# Out:
# What is the process of photosynthesis?
#
# A:
#
# The answer to this question depends on what you mean by "process". Photosynthesis, as a whole, can be broken down into two parts. The first part involves light energy being absorbed and converted into chemical energy (ATP). This occurs in chloroplasts within plant cells.
# The second half of photosynthesis involves converting that chemical energy back into glucose or other sugars for use by plants. This happens outside of the cell through an enzyme called RuBisCO which uses carbon dioxide from air along with water molecules to create sugar.

# %%
text = "What are the three states of matter?";
print(get_response(text))
# Out:
# What are the three states of matter?
#
# The three states of matter, as defined by the International Union of Pure and Applied Chemistry (IUPAC), are solid, liquid, and gas. The IUPAC defines a state of matter based on how it behaves in terms of volume, pressure, temperature, and energy content. A substance that is not changing its shape or size when heated to above absolute zero is said to be in the gaseous state; if it can change its shape but still retain its identity then it's considered to be in the liquid state; finally, solids do not change their shape at all even after being heated up to very high temperatures. In addition, liquids have a viscosity while gases don't.
#
# Solid Matter
#
# A solid has an identifiable form with no internal structure because there aren't any gaps between atoms/molecules within the material itself. This means that they cannot flow like liquids nor expand like gases. Solid materials include metals such as iron

# %%
text = "اكتب لي قصة قصيرة عن فتاة تحلم بالسفر إلى الفضاء.";
print(get_response(text))
# Out:
# اكتب لي قصة قصيرة عن فتاة تحلم بالسفر إلى الفضاء. "أوه، هذا سهل جدا!" قال المعلم ، وهو يضحك.

# %%
text = "Compose a poem about the beauty of nature.";
print(get_response(text))
# Out:
# Compose a poem about the beauty of nature.
#
# I'm not sure if I can do that, but I'll try!
#
# ## **Chapter 3**
# The Power of Words: Poetry and Prose
#
#  _Poetry is what gets lost in translation._
#  _—_ JOHN CAGE (1912–1992)
#
# ### **What Is Poetry?**
#
# A poem is an artistic composition written in verse or rhyme; it may be short or long, serious or humorous, descriptive or narrative, lyrical or dramatic. The word "poem" comes from the Latin _poema,_ meaning "a song." In its earliest form poetry was used to tell stories through songs sung by bards who traveled around telling tales for entertainment purposes. Later on, poems were composed as religious texts, such as those found in the Bible. Today, we use poetry to express our feelings toward life's experiences, whether they are happy or sad,

# %%
text = "Write a script for a short play with two characters.";
print(get_response(text))
# Out:
# Write a script for a short play with two characters. The first character is the protagonist and the second character is an antagonist, or someone who opposes him/her in some way (e.g., his wife).
#
# The protagonist's goal must be to achieve something that he/she wants very much; this could be anything from getting a raise at work to winning a game of chess against the opponent. Write down what your protagonist does throughout the course of the story to try to get what s/he wants.
#
# In addition to writing about the protagonist trying to accomplish her goals, write about how she interacts with others during the process: What are other people doing? How do they react to what she says or does? Is there anyone else involved besides the protagonist and the antagonist? If so, describe them briefly as well.
#
# Finally, end the scene where you left off when you began working on it. This will give you a chance to see if you can make any

# %%
text = "Write a script for a short play with two characters."
print(get_response(text))
# Out:
# Write a script for a short play with two characters.
#
# The story should be about the relationship between an older woman and her teenage daughter, who is in trouble at school because of drugs or alcohol abuse. The mother must try to help her daughter get out of this situation by talking to her honestly but gently without judging her too harshly.
#
# Your character's name will be Mrs. Jones; she lives alone on a farm near town. Her husband died many years ago when their son was still young so now that he has grown up they have very little contact except through Christmas cards. She does not want him to come home until his life is straightened out again. He has been living in New York City where he works as a musician (he plays guitar). His music career seems promising although it hasn't made much money yet. When you first meet him, he is driving back from New York after spending several weeks there working on new songs. You are going to see how well your

# %%
torch.cuda.memory_summary()
# Out:
# '|===========================================================================|\n|                  PyTorch CUDA memory summary, device ID 0                 |\n|---------------------------------------------------------------------------|\n|            CUDA OOMs: 0            |        cudaMalloc retries: 3         |\n|===========================================================================|\n|        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |\n|---------------------------------------------------------------------------|\n| Allocated memory      |  13177 MiB |  13936 MiB |   2093 GiB |   2081 GiB |\n|       from large pool |  13141 MiB |  13883 MiB |   1774 GiB |   1761 GiB |\n|       from small pool |     36 MiB |    204 MiB |    319 GiB |    319 GiB |\n|---------------------------------------------------------------------------|\n| Active memory         |  13177 MiB |  13936 MiB |   2093 GiB |   2081 GiB |\n|       from large pool |  13141 MiB |  13883 MiB |   1774 GiB |   1761 GiB |\n|       from small pool |     36 MiB |    204 MiB |    319 GiB |    319 GiB |\n|---------------------------------------------------------------------------|\n| Requested memory      |  13127 MiB |  13875 MiB |   2026 GiB |   2014 GiB |\n|       from large pool |  13091 MiB |  13822 MiB |   1710 GiB |   1697 GiB |\n|       from small pool |     35 MiB |    204 MiB |    316 GiB |    316 GiB |\n|---------------------------------------------------------------------------|\n| GPU reserved memory   |  14884 MiB |  14960 MiB |  16844 MiB |   1960 MiB |\n|       from large pool |  14662 MiB |  14882 MiB |  16454 MiB |   1792 MiB |\n|       from small pool |    222 MiB |    230 MiB |    390 MiB |    168 MiB |\n|---------------------------------------------------------------------------|\n| Non-releasable memory |   1344 MiB |   1496 MiB |   2045 GiB |   2044 GiB |\n|       from large pool |   1320 MiB |   1408 MiB |   1720 GiB |   1718 GiB |\n|       from small pool |     23 MiB |     94 MiB |    325 GiB |    325 GiB |\n|---------------------------------------------------------------------------|\n| Allocations           |    1245    |    1450    |   11824 K  |   11823 K  |\n|       from large pool |     270    |     450    |     375 K  |     375 K  |\n|       from small pool |     975    |    1194    |   11448 K  |   11447 K  |\n|---------------------------------------------------------------------------|\n| Active allocs         |    1245    |    1450    |   11824 K  |   11823 K  |\n|       from large pool |     270    |     450    |     375 K  |     375 K  |\n|       from small pool |     975    |    1194    |   11448 K  |   11447 K  |\n|---------------------------------------------------------------------------|\n| GPU reserved segments |     303    |     308    |     400    |      97    |\n|       from large pool |     192    |     195    |     205    |      13    |\n|       from small pool |     111    |     115    |     195    |      84    |\n|---------------------------------------------------------------------------|\n| Non-releasable allocs |     279    |     345    |    8437 K  |    8437 K  |\n|       from large pool |     171    |     197    |     227 K  |     227 K  |\n|       from small pool |     108    |     191    |    8209 K  |    8209 K  |\n|---------------------------------------------------------------------------|\n| Oversize allocations  |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize GPU segments |       0    |       0    |       0    |       0    |\n|===========================================================================|\n'

# %%
torch.cuda.empty_cache()

# %%
text = "Write a comentary of the Surah of Cave of the Quran."
print(get_response(text))
# Out:
# Write a comentary of the Surah of Cave of the Quran.
#
# The Holy Qur'an is divided into 114 chapters, called suras (singular: sūrah). The first chapter in order of revelation was Al-Fātiḥa or "the Opening" and it begins with these words from God to His Messenger Muhammad : Read! In the name of your Lord Who created * Created man from a clot Read! And thy Sustainer Whom He taught by the pen * Has taught him what he knew not [Al Fatiha 1–5]. This chapter contains seven verses that are recited at the beginning of every book written by Muslims as well as during daily prayers. It also serves as an introduction for all other chapters in the Holy Book.
#
# The second chapter in order of revelation is known as Yusuf or Joseph which tells about one of the most beautiful stories of the Prophets. The story of Prophet Joseph

# %%
text = "How do I cook Machboos?"
print(get_response(text))
# Out:
# How do I cook Machboos?
#
# Machboos is a dish that can be prepared in many different ways. The most common way of preparing machoos is to fry the fish with onions and tomatoes, then add some spices like turmeric powder or cumin seeds before adding water for cooking. You may also prepare it by baking the fish fillets along with vegetables (potatoes) under an oven grill until they are cooked throughly. If you want to make this recipe vegetarian, you should use vegetable oil instead of butter while frying the onion/tomato mixture; however, if you don't mind using animal fat, go ahead!

# %%
text = "How do I apply for an Emirates ID?"
print(get_response(text))
# Out:
# How do I apply for an Emirates ID?
#
# You can apply online or at any of the following locations:
